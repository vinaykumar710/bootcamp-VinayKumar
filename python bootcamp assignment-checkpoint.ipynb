# %% [markdown]
# # Python Bootcamp Assignment

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("student_performance - student_performance.csv")
data_frame = pd.DataFrame(df)
df.head()
# Out:
#    StudentID  G1  G2  G3      Mjob     Fjob  age address  studytime  failures  \
# 0          1   6   2   2   teacher  at_home   21   rural          3         1
# 1          2  19  11  18    health  teacher   18   rural          1         1
# 2          3  14   7  19    health    other   20   urban          1         1
# 3          4  10   2   6  services   health   21   urban          3         1
# 4          5   7   0  19    health   health   18   rural          4         1
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0        no    yes  yes        yes     yes    yes       no      yes
# 1        no     no   no         no     yes     no       no       no
# 2       yes    yes  yes         no      no     no      yes      yes
# 3       yes     no  yes         no     yes     no       no       no
# 4        no     no  yes         no     yes    yes      yes       no

# %%
df.describe()
# Out:
#         StudentID          G1          G2          G3         age  studytime  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.00000
# mean    50.500000    9.010000    8.710000    9.070000   18.180000    2.21000
# std     29.011492    5.535003    6.107282    6.629068    1.940426    1.06643
# min      1.000000    0.000000    0.000000    0.000000   15.000000    1.00000
# 25%     25.750000    4.750000    3.750000    2.000000   16.750000    1.00000
# 50%     50.500000    8.500000    8.000000    8.000000   18.000000    2.00000
# 75%     75.250000   14.000000   14.000000   15.000000   20.000000    3.00000
# max    100.000000   19.000000   19.000000   19.000000   21.000000    4.00000
#
#          failures
# count  100.000000
# mean     1.380000
# std      1.080404
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      3.000000

# %%
print(df.isnull().sum())
# Out:
# StudentID     0
# G1            0
# G2            0
# G3            0
# Mjob          0
# Fjob          0
# age           0
# address       0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# dtype: int64

# %%
df1 = pd.read_csv("ipl_matches_smalldata - ipl_matches_smalldata.csv")
ipl_data = pd.DataFrame(df1)
df1.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
#top 10 batsman data
top_batsman = df1.groupby('batter')['total_runs'].sum().sort_values(ascending = False)
top10_batsman = (top_batsman.head(10))
print(top10_batsman)
# Out:
# batter
# ML Hayden        211
# BB McCullum      200
# KC Sangakkara    180
# G Gambhir        179
# RV Uthappa       171
# MEK Hussey       170
# A Symonds        169
# SR Watson        167
# AC Gilchrist     164
# LRPL Taylor      156
# Name: total_runs, dtype: int64

# %%
mean = top10_batsman.mean()
mode = top10_batsman.mode()
print("mean of top 10 batsman :",  mean)
print("mode of top 10 batsman :", mode)
# Out:
# mean of top 10 batsman : 176.7
# mode of top 10 batsman : 0    156
# 1    164
# 2    167
# 3    169
# 4    170
# 5    171
# 6    179
# 7    180
# 8    200
# 9    211
# Name: total_runs, dtype: int64

# %%
top_batsman >= 500
# Out:
# batter
# ML Hayden        False
# BB McCullum      False
# KC Sangakkara    False
# G Gambhir        False
# RV Uthappa       False
#                  ...
# DW Steyn         False
# WA Mota          False
# MK Pandey        False
# R Vinay Kumar    False
# S Sreesanth      False
# Name: total_runs, Length: 97, dtype: bool

# %%
import matplotlib.pyplot as plt
top10_batsman.plot(kind='bar', title='Top 10 Batsman by Runs', figsize=(10, 5))
plt.xlabel('Batsman')
plt.ylabel('Total Runs')
plt.show()

# %%
#1. read an image from a file and display it using OpenCV.
import cv2
img = cv2.imread(r"rose_flower.jpg")
print(type(img))
cv2.imshow("beautyOfFlower", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
#2. Find the shape of img
print(img.shape)
# Out:
# <class 'numpy.ndarray'>
# (1600, 1204, 3)

# %%
#3. Resize the image to dimensions of 400x256 pixels.
img_resize= cv2.resize(img,(400,256))
#4. Display the resized image
cv2.imshow("ResizeImageOfFlower", img_resize)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#5. Flip the image horizontally.
img_flip= cv2.flip(img_resize,0)
cv2.imshow("Fliped Image Of Flower", img_resize)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#5. Flip the image vertically.
img_flip= cv2.flip(img_resize, 1)
cv2.imshow("Fliped Image Of Flower", img_resize)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import requests
import io

# GitHub raw URL of the dataset (replace with the actual URL of the dataset)
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"

# Download the dataset
response = requests.get(url)
if response.status_code == 200:
    data = response.content
    # Load the dataset into a DataFrame
    tips = pd.read_csv(io.StringIO(data.decode('utf-8')))
else:
    print("Failed to download dataset")
    exit()

# Count the number of people in smoking vs non-smoking areas
smoker_counts = tips['smoker'].value_counts()

# Labels and data for the pie chart
labels = ['Non-Smoking Area', 'Smoking Area']
sizes = [smoker_counts['No'], smoker_counts['Yes']]
colors = ['skyblue', 'lightcoral']
explode = (0.1, 0)  # Slightly separate the non-smoking area slice

# Plot the pie chart
plt.figure(figsize=(8, 6))
plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors,
    explode=explode,
    shadow=True )
plt.title('Percentage of People in Smoking vs Non-Smoking Areas')
plt.show()

# %%
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Ensure necessary NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')

# Example text on a topic of choice (can be replaced with your own text or file)
with open('arificial-Intelligence.txt', 'r') as file:
    text = file.read()

# Tokenize the text
tokens = nltk.word_tokenize(text.lower())

# Remove stopwords and punctuation
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in tokens if word.isalnum() and word not in stop_words]

# Create a string of the filtered words
processed_text = " ".join(filtered_words)

# Generate the word cloud
wordcloud = WordCloud(
    width=600,
    height=300,
    background_color='white',
    colormap='viridis'
).generate(processed_text)

# Display the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud on Artificial Intelligence", fontsize=16)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
